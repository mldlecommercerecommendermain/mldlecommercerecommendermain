# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt

# Algoritma adları ve dosya eşleşmeleri
algoritma_dosyalar = {
    "Random": "random_based_sonuclari.pkl",
    "Content-Based": "contant_based_sonuclari.pkl",
    "Item-Base": "item_based_sonuclari.pkl",
    "Hybrid": "hybrid_sonuclari.pkl",
    "RNN": "rnn_sonuclari.pkl",
    "Random Forest": "random_forest_sonuclari.pkl",
     "Popularity": "popularity_sonuclari.pkl"
}

# Sonuçları depolamak için boş dict
sonuclar = {}

# Tüm dosyaları yükle
for isim, dosya in algoritma_dosyalar.items():
    with open(dosya, "rb") as f:
        metrikler = pickle.load(f)
        sonuclar[isim] = metrikler
        

# Pandas DataFrame'e çevir
df_sonuclar = pd.DataFrame(sonuclar).T.round(4) # Transpose: algoritmalar satıra geçsin

# Tabloda göster
print("🔍 Algoritma Performans Sonuçları:")
display(df_sonuclar)
# Out:
# 🔍 Algoritma Performans Sonuçları:
#                   MAP      CC     MNS     MDS     MPS
# Random         0.0285  0.4002  6.9008  0.2361  0.9972
# Content-Based  0.0000  0.0020  0.5000  0.3301  0.9988
# Item-Base      0.4279  0.2379  5.0000  0.7560  0.2367
# Hybrid         0.0137  0.0112  0.5000  0.8000  0.6304
# RNN            0.0001  0.0865  1.0000  1.0000  0.0297
# Random Forest  0.3360  0.2395  3.8969  0.0000  0.3360
# Popularity     0.0014  0.0101  8.7782  0.5310  0.6483

# %%
import matplotlib.pyplot as plt

# MAP
plt.figure(figsize=(8, 5))
df_sonuclar["MAP"].plot(kind="bar", title="MAP Karşılaştırması", ylabel="MAP")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# CC
plt.figure(figsize=(8, 5))
df_sonuclar["CC"].plot(kind="bar", title="CC (Catalog Coverage) Karşılaştırması", ylabel="CC")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# MNS
plt.figure(figsize=(8, 5))
df_sonuclar["MNS"].plot(kind="bar", title="MNS (Mean Novelty Score) Karşılaştırması", ylabel="MNS")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# MDS
plt.figure(figsize=(8, 5))
df_sonuclar["MDS"].plot(kind="bar", title="MDS (Mean Diversity Score) Karşılaştırması", ylabel="MDS")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# MPS
plt.figure(figsize=(8, 5))
df_sonuclar["MPS"].plot(kind="bar", title="MPS (Mean Personalization Score) Karşılaştırması", ylabel="MPS")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
